# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Folium and geopy installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium and geopy installed
# Libraries imported.

# %%
address = 'London'

geolocator = Nominatim(user_agent="London")
location = geolocator.geocode(address)
latitude_lon = location.latitude
longitude_lon = location.longitude
print('The geograpical coordinate of London are {}, {}.'.format(latitude_lon, longitude_lon))
# Out:
# The geograpical coordinate of London are 51.5073219, -0.1276474.

# %%
address = 'Cambridge'

geolocator = Nominatim(user_agent="Cambridge")
location = geolocator.geocode(address)
latitude_cam = location.latitude
longitude_cam = location.longitude
print('The geograpical coordinate of Birmingham are {}, {}.'.format(latitude_cam, longitude_cam))
# Out:
# The geograpical coordinate of Birmingham are 52.2034823, 0.1235817.

# %%
address = 'Oxford'

geolocator = Nominatim(user_agent="Oxford")
location = geolocator.geocode(address)
latitude_ox = location.latitude
longitude_ox = location.longitude
print('The geograpical coordinate of Manchester are {}, {}.'.format(latitude_ox, longitude_ox))
# Out:
# The geograpical coordinate of Manchester are 51.7520131, -1.2578499.

# %%
CLIENT_ID = 'DCE2LO30NHDUBW2C0RURJTMR40YFWLJPNRKWKG3DPG5WGNIQ' 
CLIENT_SECRET = 'NNWSWVLHIYD0UL53BYSI0YBHFBWUQ2D3YT3H4TN3ENET35MY' 
VERSION = '20200605'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DCE2LO30NHDUBW2C0RURJTMR40YFWLJPNRKWKG3DPG5WGNIQ
# CLIENT_SECRET:NNWSWVLHIYD0UL53BYSI0YBHFBWUQ2D3YT3H4TN3ENET35MY

# %%
# Foursquare venues->search -> London

LIMIT = 100 # limit of number of venues returned by Foursquare API (Maximum 50 resposes)
search_query = 'Chinese'
radius =100000 # define radius
category = '4d4b7105d754a06374d81259' # Food

# create URL
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&categoryId={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    search_query,
    category,
    latitude_lon, 
    longitude_lon,
    radius, 
    LIMIT)

url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=DCE2LO30NHDUBW2C0RURJTMR40YFWLJPNRKWKG3DPG5WGNIQ&client_secret=NNWSWVLHIYD0UL53BYSI0YBHFBWUQ2D3YT3H4TN3ENET35MY&v=20200605&query=Chinese&categoryId=4d4b7105d754a06374d81259&ll=51.5073219,-0.1276474&radius=100000&limit=100'

# %%
# get request for results
results = requests.get(url).json()
results  # display results
# Out:
# {'meta': {'code': 200, 'requestId': '5f410305e37c686f5bf3140e'},
#  'response': {'venues': [{'id': '5c05916b340a58002ce80c2d',
#     'name': 'Imperial Treasure Fine Chinese Cuisine',
#     'location': {'address': '9 Waterloo Pl',
#      'lat': 51.507935,
#      'lng': -0.13297655,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.507935,
#        'lng': -0.13297655}],
#      'distance': 375,
#      'postalCode': 'SW1Y 4BE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9 Waterloo Pl',
#       "St. James's",
#       'Greater London',
#       'SW1Y 4BE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_lon = json_normalize(venues)

# check numbers of results returned
df_lon.shape
# Out:
# <ipython-input-8-69f152b3bd62>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_lon = json_normalize(venues)
# (50, 18)

# %%
# Foursquare venues->search -> Cambridge

LIMIT = 100 # limit of number of venues returned by Foursquare API (Maximum 50 resposes)
search_query = 'Chinese'
radius =100000 # define radius
category = '4d4b7105d754a06374d81259' # Food

# create URL
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&categoryId={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    search_query,
    category,
    latitude_cam, 
    longitude_cam,
    radius, 
    LIMIT)

url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=DCE2LO30NHDUBW2C0RURJTMR40YFWLJPNRKWKG3DPG5WGNIQ&client_secret=NNWSWVLHIYD0UL53BYSI0YBHFBWUQ2D3YT3H4TN3ENET35MY&v=20200605&query=Chinese&categoryId=4d4b7105d754a06374d81259&ll=52.2034823,0.1235817&radius=100000&limit=100'

# %%
# get request for results
results = requests.get(url).json()

# check numbers of results returned
results   # display results
# Out:
# {'meta': {'code': 200, 'requestId': '5f41004c82a8164a556bd017'},
#  'response': {'venues': [{'id': '545d0dd0498e0c7060fdd83f',
#     'name': 'Chinese Canteen',
#     'location': {'address': '30 Bridge Street',
#      'lat': 52.20969,
#      'lng': 0.117158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.20969,
#        'lng': 0.117158}],
#      'distance': 818,
#      'postalCode': 'CB2 1UJ',
#      'cc': 'GB',
#      'city': 'Cambridge',
#      'state': 'Cambridgeshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['30 Bridge Street',
#       'Cambridge',
#       'Cambridgeshire',
#       'CB2 1UJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_cam = json_normalize(venues)

# check numbers of results returned
df_cam.shape
# Out:
# <ipython-input-11-7ba9950ff7cf>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_cam = json_normalize(venues)
# (50, 18)

# %%
# Foursquare venues->search -> Oxford

LIMIT = 100 # limit of number of venues returned by Foursquare API (Maximum 50 resposes)
search_query = 'Chinese'
radius =100000 # define radius
category = '4d4b7105d754a06374d81259' # Food

# create URL
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&categoryId={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    search_query,
    category,
    latitude_ox, 
    longitude_ox,
    radius, 
    LIMIT)

url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=DCE2LO30NHDUBW2C0RURJTMR40YFWLJPNRKWKG3DPG5WGNIQ&client_secret=NNWSWVLHIYD0UL53BYSI0YBHFBWUQ2D3YT3H4TN3ENET35MY&v=20200605&query=Chinese&categoryId=4d4b7105d754a06374d81259&ll=51.7520131,-1.2578499&radius=100000&limit=100'

# %%
# get request for results
results = requests.get(url).json()
results   # display results
# Out:
# {'meta': {'code': 200, 'requestId': '5f40ffe30e78567a46201b52'},
#  'response': {'venues': [{'id': '4e7ddd18722ec0b69524c2ad',
#     'name': 'Rolin Chinese Restaurant',
#     'location': {'lat': 51.75406735507197,
#      'lng': -1.262832488359268,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.75406735507197,
#        'lng': -1.262832488359268}],
#      'distance': 412,
#      'cc': 'GB',
#      'city': 'Oxford',
#      'state': 'Oxfordshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Oxford', 'Oxfordshire', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598096078',
#     'hasPerk': False},
#    {'id': '4fedf743e4b0a516c10cc0af',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_ox = json_normalize(venues)
df_ox.shape
# Out:
# <ipython-input-14-e8337db4f1fd>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_ox = json_normalize(venues)
# (50, 19)

# %%
# Append the dataframes
df_append = df_lon.append([df_cam, df_ox])

# Remove duplicates
df_lon_cam_ox = df_append.drop_duplicates(subset=['id'])
df_lon_cam_ox.shape
print ("No of  Chinese restaurants identified around locations specified : " + str(df_lon_cam_ox.shape[0]))
# Out:
# No of  Chinese restaurants identified around locations specified : 120

# %%
df_rest = df_lon_cam_ox [['name','location.address','location.city','location.state','location.lat','location.lng']]

# %%
venues_map = folium.Map(location=[latitude_lon, longitude_lon], zoom_start=10) # generate map centred around London

# add a red circle marker to Boston
folium.features.CircleMarker(
    [latitude_lon, longitude_lon],
    radius=10,
    color='red',
    popup='London',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Chinese restaurants as blue circle markers
for lat, lng, label in zip(df_rest['location.lat'], df_rest['location.lng'], df_rest['location.city']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup='label',
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_lat_lng = df_lon_cam_ox [['location.lat', 'location.lng']]

# %%
# set number of clusters
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_lat_lng)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:67]
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 1, 1, 1, 1, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 1, 2,
#        1], dtype=int32)

# %%
# add clustering labels 
df_rest.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
# create map
map_clusters = folium.Map(location=[latitude_lon, longitude_lon], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_rest['location.lat'], df_rest['location.lng'], df_rest['location.city'], df_rest['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
